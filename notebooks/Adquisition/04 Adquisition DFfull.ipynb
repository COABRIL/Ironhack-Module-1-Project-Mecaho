# %%
import pandas as pd
import re
import numpy as np

# %%
dfforb = pd.read_csv('../../../Ironhack-Module-1-Project-Mecaho/data/raw/dfforb1.csv')
dfpop = pd.read_csv('../../../Ironhack-Module-1-Project-Mecaho/data/raw/dfpop1.csv')

# %%
dffull = dfforb.merge(dfpop, how='left', left_on='country', right_on='country')
dffull.to_csv('../../../Ironhack-Module-1-Project-Mecaho/data/raw/dffull.csv',sep=',', index = False)
dffull
# Out:
#         id             name  position  Unnamed: 0  id.1    lastName  \
# 0     5948       jeff BEzos       1.0          52  5948       beZOS
# 1     7342       BILL GAtes       2.0          53  7342       GATEs
# 2     5447   warren BUFFETT       3.0          54  5447     bufFETT
# 3     4420  bernARD ARNAULt       4.0          55  4420     aRNAULT
# 4     4071  mark ZUCKerberg       5.0          56  4071  zuckERBERg
# ...    ...              ...       ...         ...   ...         ...
# 2203  3917   ZHAO XIAOQIang    2204.0        2255  3917        zhAO
# 2204  3721  zhou liANgzhang    2205.0        2256  3721        zhOU
# 2205  6132     zhU XINGMING    2206.0        2257  6132         zHU
# 2206  7866         zhuo JUN    2207.0        2258  7866        zHUO
# 2207  2968      olGUN ZOrlu    2208.0        2259  2968       zORLU
#
#                age  Unnamed: 0.1 gender        country  ...  \
# 0     54 years old            52   None          World  ...
# ...
